# %% [markdown]
# # AI Prompt Evaluation EN/ES
#
# Review score distributions and risk flags for synthetic prompt-response examples.

# %%
from pathlib import Path
    import pandas as pd

    data_path = Path("..") / "data" / "sample_synthetic_data.csv"
    df = pd.read_csv(data_path)
    display(df.head())
    display(df.describe(include="all").transpose().head(12))
    display(df.groupby("language")[["helpfulness", "accuracy", "safety", "clarity", "bilingual_quality", "overall_score"]].mean().round(2))
